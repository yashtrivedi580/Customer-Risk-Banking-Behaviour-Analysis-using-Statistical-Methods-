# %% [markdown]
# ### step 1 : importing Necessary Libraies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as st
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### step 2 : Load the data using Pandas

# %%
data=pd.read_csv(r"C:\Users\Yash Trivedi\OneDrive\Desktop\data anlytics\stastics\bank_messy_dataset.csv")
data
# Out:
#      Customer_ID           Name   Age  Gender Account_Type  Account_Balance  \
# 0              1   Aditya Desai  56.0       M           FD      50819.73580
# 1              2      Ravi Nair  69.0    male      current      66589.47858
# 2              3  Sakshi Sharma  46.0  Female      Current      28527.41988
# 3              4      Neha Nair  32.0    Male      Savings      57285.46812
# 4              5     Amit Verma   NaN  female      Current      33419.25083
# ..           ...            ...   ...     ...          ...              ...
# 995          996    Neha Sharma  18.0  Female           FD      79182.14315
# 996          997      Karan Rao  35.0       F      Current      33372.01065
# 997          998     Sneha Nair  49.0    male      current      63951.73201
# 998          999     Ravi Desai  64.0       M      savings      49499.82587
# 999         1000    Priya Patil  66.0  female      savings      92113.54133
#
#      Loan_Amount Loan_Status  Credit_Score  Monthly_Income Employment_Status  \
# 0              0     Pending    746.354752     39442.54268     Self-Employed
# 1         200000     Pending    671.919250     42011.77000     Self-Employed
# 2              0    Approved    698.094606     33794.29135          salaried
# 3              0    Approved    752.657860     34311.31156          salaried
# 4          50000    Rejected    572.189382     39926.60102          Salaried
# ..           ...         ...           ...             ...               ...
# 995            0    approved    703.637008     46429.54365          Salaried
# 996            0     Pending    577.186440     55270.26720          salaried
# 997            0     Pending    786.163655     55039.07338          salaried
# 998       200000    Approved    522.523975     49687.38504          salaried
# 999            0    rejected    608.163262     32628.55439          Salaried
#
#      Transaction_Count         Phone    City  Late_Payments
# 0                  166  5.763597e+09    Pune              6
# 1                   71  3.101714e+09  Nagpur              0
# 2                  297  4.975047e+08  Mumbai              3
# 3                    8  5.421995e+09  Nagpur             12
# 4                  280 -5.319325e+09    Pune             14
# ..                 ...           ...     ...            ...
# 995                237  3.611607e+09  Mumbai             10
# 996                134           NaN   delhi             12
# 997                279  5.611354e+08  mumbai             14
# 998                 18  5.115705e+09  mumbai              1
# 999                 82 -1.476844e+09  Nagpur             14
#
# [1000 rows x 15 columns]

# %% [markdown]
# ### step 3 : Data Understanding
# 1. Customer_ID
# - Type: Numerical (Discrete)
# - Description: Unique identifier assigned to each customer.
# - Notes: Used for record tracking; no analytical meaning.
# 2. Name
# - Type: Categorical (Nominal)
# - Description: Full name of the customer.
# - Notes: May include inconsistent formats (upper/lowercase, extra spaces).
# 3. Age
# - Type: Numerical (Continuous)
# - Description: Age of the customer in years.
# - Notes: May contain missing values or unrealistic ages (e.g., <18 or >90).
# 4. Gender
# - Type: Categorical (Nominal)
# - Description: Gender of the customer (Male/Female).
# - Notes: Includes inconsistent entries (e.g., “M”, “male”, “FEMALE”, “f”).
# 5. Account_Type
# - Type: Categorical (Nominal)
# - Description: Type of bank account held (Savings, Current, Salary, Joint).
# - Notes: Contains typos and mixed-format values.
# 6. Account_Balance
# - Type: Numerical (Continuous)
# - Description: Current available balance in the customer’s account (INR).
# - Notes: Contains outliers and missing values.
# 7. Loan_Amount
# - Type: Numerical (Continuous)
# - Description: Total sanctioned loan amount for the customer.
# - Notes: May include extreme values and incorrect entries.
# 8. Loan_Status
# - Type: Categorical (Nominal)
# - Description: Status of the customer’s loan (Approved / Rejected / Pending).
# - Notes: Includes inconsistent labels (“APPROVED”, “approved”, “A”, etc.).
# 9. Credit_Score
# - Type: Numerical (Continuous)
# - Description: Credit rating of the customer (300–900 scale).
# - Notes: Outliers possible; useful for credit risk analysis.
# 10. Monthly_Income
# - Type: Numerical (Continuous)
# - Description: Customer’s monthly income in INR.
# - Notes: Contains missing values and noise.
# 11. Employment_Status
# - Type: Categorical (Nominal)
# - Description: Type of employment (Salaried, Self-Employed, Unemployed, Student).
# - Notes: May contain typos and inconsistent capitalization.
# 12. Transaction_Count
# - Type: Numerical (Discrete)
# - Description: Number of monthly bank transactions made by the customer.
# - Notes: Missing values possible; used in behavior-based segmentation.
# 13. Phone
# - Type: Categorical (Nominal)
# - Description: Customer’s phone number.
# - Notes: Contains formatting inconsistencies, missing digits, symbols.
# 14. City
# - Type: Categorical (Nominal)
# - Description: Customer’s city of residence.
# - Notes: Contains NULLs and inconsistent spellings (e.g., “Mumbai”, “mumbai”, “Bombay”).
# 15. Late_Payments
# - Type: Numerical (Discrete)
# - Description: Number of late EMI/credit-card payments recorded.
# - Notes: May include extremely high values due to input errors.
# Includes missing values, outliers, inconsistent formats, categorical noise, typos, mixed data types.

# %% [markdown]
# ### Step 4 : EDA (Exploratory Data Analysis)
# - Describe the data statistically
#    - shape
#    - describe
#    - info
#    - dtypes
#    - null value checking
#    - duplicate values checking
# - missing value Handling
# - Outlier Handling
# - univariate and bivariate Analysis to understand each and every column

# %%
data.shape
# Out:
# (1000, 15)

# %%
data.columns
# Out:
# Index(['Customer_ID', 'Name', 'Age', 'Gender', 'Account_Type',
#        'Account_Balance', 'Loan_Amount', 'Loan_Status', 'Credit_Score',
#        'Monthly_Income', 'Employment_Status', 'Transaction_Count', 'Phone',
#        'City', 'Late_Payments'],
#       dtype='object')

# %%
data2=data[['Age', 'Gender', 'Account_Type',
       'Account_Balance', 'Loan_Amount', 'Loan_Status', 'Credit_Score',
       'Monthly_Income', 'Employment_Status', 'Transaction_Count',
       'City', 'Late_Payments']]
data2
# Out:
#       Age  Gender Account_Type  Account_Balance  Loan_Amount Loan_Status  \
# 0    56.0       M           FD      50819.73580            0     Pending
# 1    69.0    male      current      66589.47858       200000     Pending
# 2    46.0  Female      Current      28527.41988            0    Approved
# 3    32.0    Male      Savings      57285.46812            0    Approved
# 4     NaN  female      Current      33419.25083        50000    Rejected
# ..    ...     ...          ...              ...          ...         ...
# 995  18.0  Female           FD      79182.14315            0    approved
# 996  35.0       F      Current      33372.01065            0     Pending
# 997  49.0    male      current      63951.73201            0     Pending
# 998  64.0       M      savings      49499.82587       200000    Approved
# 999  66.0  female      savings      92113.54133            0    rejected
#
#      Credit_Score  Monthly_Income Employment_Status  Transaction_Count  \
# 0      746.354752     39442.54268     Self-Employed                166
# 1      671.919250     42011.77000     Self-Employed                 71
# 2      698.094606     33794.29135          salaried                297
# 3      752.657860     34311.31156          salaried                  8
# 4      572.189382     39926.60102          Salaried                280
# ..            ...             ...               ...                ...
# 995    703.637008     46429.54365          Salaried                237
# 996    577.186440     55270.26720          salaried                134
# 997    786.163655     55039.07338          salaried                279
# 998    522.523975     49687.38504          salaried                 18
# 999    608.163262     32628.55439          Salaried                 82
#
#        City  Late_Payments
# 0      Pune              6
# 1    Nagpur              0
# 2    Mumbai              3
# 3    Nagpur             12
# 4      Pune             14
# ..      ...            ...
# 995  Mumbai             10
# 996   delhi             12
# 997  mumbai             14
# 998  mumbai              1
# 999  Nagpur             14
#
# [1000 rows x 12 columns]

# %%
data2.shape
# Out:
# (1000, 12)

# %% [markdown]
# There are 1000 row and 15 columns in our data.but we can remove "customer id","customer_name","phone" columnn bcoz they are not important for the analysis
# so after the removing column we have 12 columns and the 1000 rows

# %%
data2.dtypes
# Out:
# Age                  float64
# Gender                object
# Account_Type          object
# Account_Balance      float64
# Loan_Amount            int64
# Loan_Status           object
# Credit_Score         float64
# Monthly_Income       float64
# Employment_Status     object
# Transaction_Count      int64
# City                  object
# Late_Payments          int64
# dtype: object

# %%
data2.describe()
# Out:
#               Age  Account_Balance    Loan_Amount  Credit_Score  \
# count  950.000000       952.000000    1000.000000    950.000000
# mean    49.902105     55554.478106   98450.000000    648.575835
# std     18.201422     50552.331223  110554.601079     72.665158
# min     18.000000    -17736.275230       0.000000    439.465736
# 25%     35.000000     37611.782088       0.000000    599.106122
# 50%     50.000000     51678.633790   50000.000000    649.829288
# 75%     66.000000     64629.400415  200000.000000    695.994639
# max     79.000000    508073.265200  300000.000000    877.016508
#
#        Monthly_Income  Transaction_Count  Late_Payments
# count      950.000000        1000.000000    1000.000000
# mean     34770.683184         150.962000       6.954000
# std      11771.368205          86.583389       4.309113
# min      -3120.445758           0.000000       0.000000
# 25%      27098.578487          75.750000       3.000000
# 50%      34756.044145         153.000000       7.000000
# 75%      42869.240728         227.000000      11.000000
# max      72354.922410         299.000000      14.000000

# %% [markdown]
# ### age
# - mean	49.902105
# - median 50.00
# - std	18.201422
# - max   79
# - when std < mean there are No Outliers present in Age column

# %% [markdown]
# #### Loan Amount
# - Mean   =  00.00
# - median = 	50000
# - std    =  110554.60
# - when std > mean there will be outliers

# %% [markdown]
# #### Account_Balance
# - Mean   = 55554.47
# - median = 51678.6
# - std    = 50552.3
# - when std < mean there is no outliers

# %% [markdown]
# #### Credit_Score
# - Mean   = 648.57
# - median = 649.829
# - std    = 72.66
# - when std < mean there is no outliers

# %% [markdown]
# #### Monthly_Income
# - Mean   = 34770.68
# - median = 34756.04
# - std    = 11771.36
# - when std < mean there is no outliers

# %% [markdown]
# #### Transaction_Count
# - Mean   = 150.96
# - median = 153.000
# - std    = 86.58
# - when std < mean there is no outliers

# %% [markdown]
# #### Late_Payments
# - Mean   = 6.954
# - median = 7.000
# - std    = 84.3091
# - when std < mean there is no outliers

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                950 non-null    float64
#  1   Gender             1000 non-null   object
#  2   Account_Type       1000 non-null   object
#  3   Account_Balance    952 non-null    float64
#  4   Loan_Amount        1000 non-null   int64
#  5   Loan_Status        1000 non-null   object
#  6   Credit_Score       950 non-null    float64
#  7   Monthly_Income     950 non-null    float64
#  8   Employment_Status  1000 non-null   object
#  9   Transaction_Count  1000 non-null   int64
#  10  City               1000 non-null   object
#  11  Late_Payments      1000 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 93.9+ KB

# %%
data2.head()
# Out:
#     Age  Gender Account_Type  Account_Balance  Loan_Amount Loan_Status  \
# 0  56.0       M           FD      50819.73580            0     Pending
# 1  69.0    male      current      66589.47858       200000     Pending
# 2  46.0  Female      Current      28527.41988            0    Approved
# 3  32.0    Male      Savings      57285.46812            0    Approved
# 4   NaN  female      Current      33419.25083        50000    Rejected
#
#    Credit_Score  Monthly_Income Employment_Status  Transaction_Count    City  \
# 0    746.354752     39442.54268     Self-Employed                166    Pune
# 1    671.919250     42011.77000     Self-Employed                 71  Nagpur
# 2    698.094606     33794.29135          salaried                297  Mumbai
# 3    752.657860     34311.31156          salaried                  8  Nagpur
# 4    572.189382     39926.60102          Salaried                280    Pune
#
#    Late_Payments
# 0              6
# 1              0
# 2              3
# 3             12
# 4             14

# %%
data2.sample(5)
# Out:
#       Age  Gender Account_Type  Account_Balance  Loan_Amount Loan_Status  \
# 110  77.0  female           FD      57123.33754            0    Rejected
# 594  75.0  Female      Current      58506.04808        50000    approved
# 325  46.0    male           FD      35690.56606            0    rejected
# 514  56.0    male           FD      39091.08002       300000    Rejected
# 496  41.0    Male      current      56487.99944        50000    rejected
#
#      Credit_Score  Monthly_Income Employment_Status  Transaction_Count  \
# 110    660.455444     43441.28160          salaried                 66
# 594    712.391258     26691.79071          Salaried                248
# 325    719.728275     28734.42116     Self-Employed                224
# 514    717.339103     33337.85306          Salaried                 76
# 496    664.333122     40989.14979        Unemployed                299
#
#        City  Late_Payments
# 110   delhi              6
# 594  Nagpur             13
# 325  Nagpur             14
# 514    Pune             12
# 496   delhi              3

# %%
data2.tail()
# Out:
#       Age  Gender Account_Type  Account_Balance  Loan_Amount Loan_Status  \
# 995  18.0  Female           FD      79182.14315            0    approved
# 996  35.0       F      Current      33372.01065            0     Pending
# 997  49.0    male      current      63951.73201            0     Pending
# 998  64.0       M      savings      49499.82587       200000    Approved
# 999  66.0  female      savings      92113.54133            0    rejected
#
#      Credit_Score  Monthly_Income Employment_Status  Transaction_Count  \
# 995    703.637008     46429.54365          Salaried                237
# 996    577.186440     55270.26720          salaried                134
# 997    786.163655     55039.07338          salaried                279
# 998    522.523975     49687.38504          salaried                 18
# 999    608.163262     32628.55439          Salaried                 82
#
#        City  Late_Payments
# 995  Mumbai             10
# 996   delhi             12
# 997  mumbai             14
# 998  mumbai              1
# 999  Nagpur             14

# %% [markdown]
# ### checking inconsitent data in each categorical column

# %%
numeric_cols = data2.select_dtypes(include=['number'])
numeric_cols
# Out:
#       Age  Account_Balance  Loan_Amount  Credit_Score  Monthly_Income  \
# 0    56.0      50819.73580            0    746.354752     39442.54268
# 1    69.0      66589.47858       200000    671.919250     42011.77000
# 2    46.0      28527.41988            0    698.094606     33794.29135
# 3    32.0      57285.46812            0    752.657860     34311.31156
# 4     NaN      33419.25083        50000    572.189382     39926.60102
# ..    ...              ...          ...           ...             ...
# 995  18.0      79182.14315            0    703.637008     46429.54365
# 996  35.0      33372.01065            0    577.186440     55270.26720
# 997  49.0      63951.73201            0    786.163655     55039.07338
# 998  64.0      49499.82587       200000    522.523975     49687.38504
# 999  66.0      92113.54133            0    608.163262     32628.55439
#
#      Transaction_Count  Late_Payments
# 0                  166              6
# 1                   71              0
# 2                  297              3
# 3                    8             12
# 4                  280             14
# ..                 ...            ...
# 995                237             10
# 996                134             12
# 997                279             14
# 998                 18              1
# 999                 82             14
#
# [1000 rows x 7 columns]

# %%
categorical_cols = data2.select_dtypes(include=['object', 'category'])
categorical_cols
# Out:
#      Gender Account_Type Loan_Status Employment_Status    City
# 0         M           FD     Pending     Self-Employed    Pune
# 1      male      current     Pending     Self-Employed  Nagpur
# 2    Female      Current    Approved          salaried  Mumbai
# 3      Male      Savings    Approved          salaried  Nagpur
# 4    female      Current    Rejected          Salaried    Pune
# ..      ...          ...         ...               ...     ...
# 995  Female           FD    approved          Salaried  Mumbai
# 996       F      Current     Pending          salaried   delhi
# 997    male      current     Pending          salaried  mumbai
# 998       M      savings    Approved          salaried  mumbai
# 999  female      savings    rejected          Salaried  Nagpur
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### checking the unique values in categorical data in each columns

# %%
categorical_cols["Gender"].unique()
# Out:
# array(['M', 'male', 'Female', 'Male', 'female', 'F'], dtype=object)

# %%
categorical_cols["Account_Type"].unique()
# Out:
# array(['FD', 'current', 'Current', 'Savings', 'Loan', 'savings'],
#       dtype=object)

# %%
categorical_cols["City"].unique()
# Out:
# array(['Pune', 'Nagpur', 'Mumbai', 'mumbai', 'Thane', 'delhi', 'Delhi'],
#       dtype=object)

# %%
categorical_cols["Employment_Status"].unique()
# Out:
# array(['Self-Employed', 'salaried', 'Salaried', 'Unemployed'],
#       dtype=object)

# %%
categorical_cols["Loan_Status"].unique()
# Out:
# array(['Pending', 'Approved', 'Rejected', 'rejected', 'approved'],
#       dtype=object)

# %% [markdown]
# ### Replace Categories Values

# %%
data2["Gender"]=data2["Gender"].replace(["M","male"],"Male")
data2["Gender"]=data2["Gender"].replace(["F","female"],"Female")

# %%
data2["Account_Type"]=data2["Account_Type"].replace("current",'Current')
data2["Account_Type"]=data2["Account_Type"].replace('savings', 'Savings')

# %%
data2["City"]=data2["City"].replace("delhi",'Delhi')
data2["City"]=data2["City"].replace('mumbai', 'Mumbai')

# %%
data2["Employment_Status"]=data2["Employment_Status"].replace('salaried', 'Salaried')

# %%
data2["Loan_Status"]=data2["Loan_Status"].replace('rejected','Rejected')
data2["Loan_Status"]=data2["Loan_Status"].replace('approved','Approved')

# %%
data2
# Out:
#       Age  Gender Account_Type  Account_Balance  Loan_Amount Loan_Status  \
# 0    56.0    Male           FD      50819.73580            0     Pending
# 1    69.0    Male      Current      66589.47858       200000     Pending
# 2    46.0  Female      Current      28527.41988            0    Approved
# 3    32.0    Male      Savings      57285.46812            0    Approved
# 4     NaN  Female      Current      33419.25083        50000    Rejected
# ..    ...     ...          ...              ...          ...         ...
# 995  18.0  Female           FD      79182.14315            0    Approved
# 996  35.0  Female      Current      33372.01065            0     Pending
# 997  49.0    Male      Current      63951.73201            0     Pending
# 998  64.0    Male      Savings      49499.82587       200000    Approved
# 999  66.0  Female      Savings      92113.54133            0    Rejected
#
#      Credit_Score  Monthly_Income Employment_Status  Transaction_Count  \
# 0      746.354752     39442.54268     Self-Employed                166
# 1      671.919250     42011.77000     Self-Employed                 71
# 2      698.094606     33794.29135          Salaried                297
# 3      752.657860     34311.31156          Salaried                  8
# 4      572.189382     39926.60102          Salaried                280
# ..            ...             ...               ...                ...
# 995    703.637008     46429.54365          Salaried                237
# 996    577.186440     55270.26720          Salaried                134
# 997    786.163655     55039.07338          Salaried                279
# 998    522.523975     49687.38504          Salaried                 18
# 999    608.163262     32628.55439          Salaried                 82
#
#        City  Late_Payments
# 0      Pune              6
# 1    Nagpur              0
# 2    Mumbai              3
# 3    Nagpur             12
# 4      Pune             14
# ..      ...            ...
# 995  Mumbai             10
# 996   Delhi             12
# 997  Mumbai             14
# 998  Mumbai              1
# 999  Nagpur             14
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### Handling Null Values

# %% [markdown]
# to check % of null values present in a dataset

# %%
data2.isnull().sum()/1000*100
# Out:
# Age                  5.0
# Gender               0.0
# Account_Type         0.0
# Account_Balance      4.8
# Loan_Amount          0.0
# Loan_Status          0.0
# Credit_Score         5.0
# Monthly_Income       5.0
# Employment_Status    0.0
# Transaction_Count    0.0
# City                 0.0
# Late_Payments        0.0
# dtype: float64

# %% [markdown]
# #### if there is more than 30 % null values present in any column we can directly drop that column if not important for analysis
# - age : Mean (No Outliers)
# - Acount_balance: medium( outliers are present)
# - Credit_score : mean (No Outliers)
# - Monthly income : mean (No outliers)

# %%
data2["Age"]=data2["Age"].fillna(data2["Age"].mean())

# %%
data2["Account_Balance"]=data2["Account_Balance"].fillna(data2["Account_Balance"].median())

# %%
data2["Credit_Score"]=data2["Credit_Score"].fillna(data2["Credit_Score"].mean())

# %%
data2["Monthly_Income"]=data2["Monthly_Income"].fillna(data2["Monthly_Income"].mean())

# %%
data2.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Account_Type         0
# Account_Balance      0
# Loan_Amount          0
# Loan_Status          0
# Credit_Score         0
# Monthly_Income       0
# Employment_Status    0
# Transaction_Count    0
# City                 0
# Late_Payments        0
# dtype: int64

# %%
sns.heatmap(data2.isnull())
plt.show()

# %% [markdown]
# ### here we fill the null values thats why heatmap are not showing  null values

# %%
data2.corr(numeric_only=True)
# Out:
#                         Age  Account_Balance  Loan_Amount  Credit_Score  \
# Age                1.000000        -0.004921    -0.024750     -0.075933
# Account_Balance   -0.004921         1.000000     0.007787      0.059364
# Loan_Amount       -0.024750         0.007787     1.000000      0.007364
# Credit_Score      -0.075933         0.059364     0.007364      1.000000
# Monthly_Income     0.035958        -0.006548    -0.019099     -0.005324
# Transaction_Count -0.060662         0.068070     0.000789      0.033136
# Late_Payments     -0.000531        -0.024898    -0.028831     -0.047880
#
#                    Monthly_Income  Transaction_Count  Late_Payments
# Age                      0.035958          -0.060662      -0.000531
# Account_Balance         -0.006548           0.068070      -0.024898
# Loan_Amount             -0.019099           0.000789      -0.028831
# Credit_Score            -0.005324           0.033136      -0.047880
# Monthly_Income           1.000000           0.007620      -0.009469
# Transaction_Count        0.007620           1.000000       0.016021
# Late_Payments           -0.009469           0.016021       1.000000

# %%
sns.heatmap(numeric_cols.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation between Numeric columns")
# Out:
# Text(0.5, 1.0, 'Correlation between Numeric columns')

# %% [markdown]
# #### there is no strong correaltion between the numeric columns

# %% [markdown]
# ### Outlier Detection And Treatment
# - to check if there are outliers present in numeric columns
# 1. kde plot
# 2. boxplot
# 3. IQR
# 4. Zscore

# %% [markdown]
# #### age data

# %%
sns.boxplot(data=data2,x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.kdeplot(data=data2,x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
from scipy.stats import kurtosis,skew
skewness=skew(data2["Age"])
print(skewness)
kurtosis_=kurtosis(data2["Age"])
print(kurtosis_)
# Out:
# -0.07427752320769702
# -1.0788852205997763

# %% [markdown]
# #### account balance data

# %%
sns.boxplot(data2.Account_Balance)
# Out:
# <Axes: ylabel='Account_Balance'>

# %%
sns.kdeplot(data2.Account_Balance)
# Out:
# <Axes: xlabel='Account_Balance', ylabel='Density'>

# %%
sns.displot(data2.Account_Balance)

# %%
skewness=skew(data2["Account_Balance"])
print(skewness)
kurtosis_=kurtosis(data2["Account_Balance"])
print(kurtosis_)
# Out:
# 7.695609595419681
# 68.15131344868567

# %%
# by using zscore
from scipy.stats import zscore
outlier=[]
for i in zscore(data2["Account_Balance"]):
    if abs(i)>3:
        outlier.append(i)
print(outlier)
print(len(outlier))
# Out:
# [np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953), np.float64(9.181684256145953)]
# 10

# %% [markdown]
# #### Credit Score data

# %%
sns.kdeplot(data2.Credit_Score)
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Density'>

# %%
sns.boxplot(data2.Credit_Score)
# Out:
# <Axes: ylabel='Credit_Score'>

# %%
sns.displot(data2.Credit_Score)

# %% [markdown]
# ### capping the Outlier : replace
# - replace all values below the 1st percentilr with  1st percentile
# - replace all values above the 99th percentile with the 99th percentile

# %%
data2.loc(data2["Account_Balance"]<0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10916\675970652.py in ?()
# ----> 1 data2.loc(data2["Account_Balance"]<0)
#
# c:\Users\Yash Trivedi\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# --> 738             axis_int_none = self.obj._get_axis_number(axis)
#     739         else:
#     740             axis_int_none = axis
#     741         new_self.axis = axis_int_none
#
# c:\Users\Yash Trivedi\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     573     @classmethod
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
# --> 577         except KeyError:
#     578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'

# %%
first_percentile=np.percentile(data2["Account_Balance"],1)
N99_percentile=np.percentile(data2["Account_Balance"],99)

# %%
print(first_percentile)
print(N99_percentile)
# Out:
# 5515.6522147000005
# 123799.11289399647

# %%
data2["Account_Balance"]=data2["Account_Balance"].clip(first_percentile,N99_percentile)

# %%
sns.kdeplot(data2.Account_Balance)
# Out:
# <Axes: xlabel='Account_Balance', ylabel='Density'>
